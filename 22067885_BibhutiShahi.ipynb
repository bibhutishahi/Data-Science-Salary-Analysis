# %%
#Write a python program that loads data into pandas dataframe.

import pandas as pd

#Loading the data into the pandas.

dataSet = pd.read_csv("SalarySheet.csv")
df = pd.DataFrame(dataSet)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
#Write a python program to remove the unnecessary columns i.e., salary and salary currency.

unnecessaryColumns = ['salary', 'salary_currency']
df= df.drop(columns = unnecessaryColumns)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
#Write a python program to remove the NaN missing values from updated DataFrame.

df = df.dropna()
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
#Write a python program to check duplicates value in the dataframe.

duplicatevalues = df[df.duplicated()]
duplicatevalues
# Out:
#       work_year experience_level employment_type           job_title  \
# 115        2023               SE              FT      Data Scientist
# 123        2023               SE              FT  Analytics Engineer
# 153        2023               MI              FT       Data Engineer
# 154        2023               MI              FT       Data Engineer
# 160        2023               SE              FT       Data Engineer
# ...         ...              ...             ...                 ...
# 3439       2022               MI              FT      Data Scientist
# 3440       2022               SE              FT       Data Engineer
# 3441       2022               SE              FT       Data Engineer
# 3586       2021               MI              FT       Data Engineer
# 3709       2021               MI              FT      Data Scientist
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %%
#Write a python program to see the unique values from all the columns in the dataframe

#Creating an empty dictionary to store thevalues

unique_values_dictionary = {}

#Iterating through each column into the Dataframe

for column in df.columns:
    unique_values_dictionary[column] = df[column].unique()
    
#Displaying unique values of each of the column

for column, values in unique_values_dictionary.items():
    print(f"The unique values in the column '{column}':")
    print(values)
    print()
# Out:
# The unique values in the column 'work_year':
# [2023 2022 2020 2021]
#
# The unique values in the column 'experience_level':
# ['SE' 'MI' 'EN' 'EX']
#
# The unique values in the column 'employment_type':
# ['FT' 'CT' 'FL' 'PT']
#
# The unique values in the column 'job_title':
# ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
# ...

# %%
#Renaming the post to senior level

df['experience_level'] = df['experience_level'].replace("SE" , "Senior Level")
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior Level              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023     Senior Level              FT            Data Scientist
# 4          2023     Senior Level              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior Level              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021     Senior Level              FT      Data Science Manager
#
# ...

# %%
#Renaming MI level to Medium level

df['experience_level'] = df['experience_level'].replace("MI" ," Medium Level")
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior Level              FT  Principal Data Scientist
# 1          2023     Medium Level              CT               ML Engineer
# 2          2023     Medium Level              CT               ML Engineer
# 3          2023     Senior Level              FT            Data Scientist
# 4          2023     Senior Level              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior Level              FT            Data Scientist
# 3751       2021     Medium Level              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021     Senior Level              FT      Data Science Manager
#
# ...

# %%
#Renaming EN to Entry Level

df['experience_level'] = df['experience_level'].replace("EN", "Entry Level")
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023     Senior Level              FT  Principal Data Scientist
# 1          2023     Medium Level              CT               ML Engineer
# 2          2023     Medium Level              CT               ML Engineer
# 3          2023     Senior Level              FT            Data Scientist
# 4          2023     Senior Level              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020     Senior Level              FT            Data Scientist
# 3751       2021     Medium Level              FT  Principal Data Scientist
# 3752       2020      Entry Level              FT            Data Scientist
# 3753       2020      Entry Level              CT     Business Data Analyst
# 3754       2021     Senior Level              FT      Data Science Manager
#
# ...

# %%
#Renaming EX level to Execute level

df['experience_level'] = df['experience_level'].replace("EX", "Execute Level")
execute_level = df[df['experience_level'] == 'Execute Level']
execute_level
# Out:
#       work_year experience_level employment_type                 job_title  \
# 58         2023    Execute Level              FT            Data Scientist
# 59         2023    Execute Level              FT            Data Scientist
# 183        2020    Execute Level              FT        Staff Data Analyst
# 203        2023    Execute Level              FT             Data Engineer
# 204        2023    Execute Level              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 3559       2020    Execute Level              FT             Data Engineer
# 3643       2021    Execute Level              FT  Director of Data Science
# 3660       2021    Execute Level              FT   Data Science Consultant
# 3675       2021    Execute Level              CT  Principal Data Scientist
# 3697       2020    Execute Level              FT  Director of Data Science
#
# ...

# %%
#write a Python program to show summary statistics of sum, mean, standard deviation, skewness, and kurtosis of any chosen variable

# Asking user for column

chosenvariable = input("Enter the name of the variable you want to analyze: ") 

# Verifying if the chosen variable exists in the df DataFrame 

if chosenvariable in df.columns: 
    # Describing method to get all the statistics 
    summarystats = df[chosenvariable].describe() 
    
    # Calculating skewness and kurtosis 
    skewness = df[chosenvariable].skew() 
    kurtosis = df[chosenvariable].kurtosis() 
    
    # Displaying the summary statistics 
    print ("Summary Statistics:") 
    print (summarystats)
    print("\nAdditional Statistics:") 
    print(f"Skewness: {skewness}") 
    print(f"Kurtosis: {kurtosis}") 
else: 
    print(f"Error: The variable '{chosenvariable}' does not exist in the DataFrame.")
# Out:
# Enter the name of the variable you want to analyze: salary_in_usd
# Summary Statistics:
# count      3755.000000
# mean     137570.389880
# std       63055.625278
# min        5132.000000
# 25%       95000.000000
# 50%      135000.000000
# 75%      175000.000000
# max      450000.000000
# Name: salary_in_usd, dtype: float64
#
# Additional Statistics:
# Skewness: 0.5364011659712974
# Kurtosis: 0.8340064594833612

# %%
# Select only numeric columns as pandas cannot calculate correlation for strings 

numericdf = df.select_dtypes (include=['number']) 

#Calculating the correlation of the numeric values 

correlation_matrix = numericdf.corr()

# Displaying the correlation matrix 
print("Correlation Matrix:") 
print (correlation_matrix)
# Out:
# Correlation Matrix:
#                work_year  salary_in_usd  remote_ratio
# work_year        1.00000       0.228290     -0.236430
# salary_in_usd    0.22829       1.000000     -0.064171
# remote_ratio    -0.23643      -0.064171      1.000000

# %%
#Finding the top 15 jobs 
#count - count unique values 
#head(15) - to display the top 15 details/ 
#tolist() - converted to List for better display and easier manipulation 

Top_Fifteen_Jobs = df['job_title'].value_counts().head(15).index.tolist() 
Top_Fifteen_Jobs
# Out:
# ['Data Engineer',
#  'Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Analytics Engineer',
#  'Data Architect',
#  'Research Scientist',
#  'Data Science Manager',
#  'Applied Scientist',
#  'Research Engineer',
#  'ML Engineer',
#  'Data Manager',
#  'Machine Learning Scientist',
#  'Data Science Consultant',
#  'Data Analytics Manager']

# %%
import matplotlib.pyplot as plt 
import numpy as np 

#Finding the top 15 jobs 
#count - count unique values 
#head(15) - to display the top 15 details/ 
#tolist) - converted to List for better display and easier manipulation 

Top_Fifteen_Jobs = df['job_title'].value_counts().head(15).index.tolist() 
Top_Fifteen_Jobs 
y= Top_Fifteen_Jobs
x= np.arange(1,16) 
plt.bar(x,y) 
plt.xlabel("Count") 
plt. ylabel("Top jobs")
# Out:
# Text(0, 0.5, 'Top jobs')

# %%
#Write a program to find out the job with highest salary with bar graph 

highest_salary = df.groupby('job_title')['salary_in_usd'].max().sort_values(ascending=False).head(20)

#Plotting the bar graph
plt.figure(figsize=(15, 10))
highest_salary.plot(kind='bar')
plt.xlabel('Job Title')
plt.ylabel('Salary (USD)')
plt.title('Top Salary by Job Title')
plt.xticks(rotation=90)
plt.show()

# %%
#Write a python program to find out salaries based on experience Level 

salary_basedonexperience = df.groupby('experience_level')['salary_in_usd'].max()
salary_basedonexperience
# Out:
# experience_level
#  Medium Level    450000
# Entry Level      300000
# Execute Level    416000
# Senior Level     423834
# Name: salary_in_usd, dtype: int64

# %%
#Showcasing in the graph 

x = df['experience_level'] 
y = df['salary_in_usd']
plt.bar(x,y)
# Out:
# <BarContainer object of 3755 artists>

# %%
#Plotting the histogram for the salary_in_usd
df.hist(column = 'salary_in_usd')
plt.title('Histogram of Salary')
plt.xlabel('Salary')
plt.ylabel('count')
plt.show()

# %%
#Plotting the box plot for the salary_in_usd
df.boxplot(column = 'salary_in_usd')
plt.title('Boxplot of Salary')
plt.ylabel('salary')
plt.show()
